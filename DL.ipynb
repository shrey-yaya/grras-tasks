# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.21.0

# %%
#ANN
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#model

# %%
# cnn
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPool2D,Flatten,Dense

# %%
# rnn
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN,Dense

# %%
# lstm -> improved version of rnn
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense

# model

# %%
# gru -> improved version of rnn
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU,Dense

# model

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab') # new line add

from nltk.tokenize import word_tokenize

text = "I Love Machine Learning"
tokens = word_tokenize(text) # tokenize
print(tokens)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUSS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ASUSS\AppData\Roaming\nltk_data...
# ['I', 'Love', 'Machine', 'Learning']
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
import nltk


from nltk.tokenize import word_tokenize

text = "Shreya"
tokens = word_tokenize(text) # tokenize
print(tokens)
# Out:
# ['Shreya']

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
text = "I am Learning Machine Learning with Rajendra"

words = word_tokenize(text)
print("tokenize")
print(words)

stop_words = set(stopwords.words("english"))
print("stop words")
print(stop_words)

# filter data
filtered = []

for word in words:
    if word.lower() not in stop_words:
        filtered.append(word)

# print filter data
print("filter data:-")
print(filtered)
# Out:
# tokenize
# ['I', 'am', 'Learning', 'Machine', 'Learning', 'with', 'Rajendra']
# stop words
# {'yourselves', 'both', "i've", 'from', 'off', 'because', "won't", "she'll", "i'd", 's', 'than', "needn't", "mustn't", 'being', 'through', 'while', "that'll", 'be', 'no', 'him', 'not', 'ourselves', 'an', 'he', 'my', 'myself', 'shan', 'why', 'or', 'so', 'here', 'with', 'this', 'weren', 'll', "couldn't", 'she', 'has', 'after', 'had', 'were', "you've", 'isn', 'which', 'over', 'hasn', 'ma', "we'll", 'some', 'into', 'their', 'these', "we're", 'hadn', "you're", 'below', "doesn't", 'all', 'and', 'shouldn', "it'd", 'aren', 'the', 'it', 'such', 'wouldn', 'can', 'each', 'nor', 'same', "mightn't", 'you', 'that', 'm', 'your', "you'll", 'to', 'between', 'only', 'i', 'we', 'its', 'are', 'other', 'should', 'once', 'under', 'those', 'himself', 'do', "hadn't", 'as', 'if', 'doing', 'above', 'of', 'o', 'ours', "should've", 'during', 'by', 'but', "he's", 'was', "we've", 'until', "didn't", 'have', "he'd", 'herself', 't', 'them', 'his', "they're", "we'd", 'whom', 'most', "i'm", "you'd", 'up', "shan't", 'for', 'too', 'when', 'any', 'needn', 'theirs', 'didn', 'don', "i'll", 'her', "hasn't", "wasn't", 're', 'y', 'ain', 'before', 'then', 'couldn', 'our', 'what', "don't", "she'd", 'wasn', 'more', 'a', 'd', "they've", 'in', 'is', 'will', 'just', 'themselves', "haven't", 'who', 'again', 'out', 'very', 'yours', 'itself', "wouldn't", "it'll", 'haven', 'against', 've', "aren't", "it's", "she's", 'further', 'been', "they'll", "he'll", "they'd", "shouldn't", 'won', 'did', 'now', "weren't", 'where', 'yourself', 'doesn', 'they', 'there', 'having', 'few', 'how', 'on', "isn't", 'hers', 'does', 'down', 'mustn', 'about', 'me', 'mightn', 'at', 'am', 'own'}
# filter data:-
# ['Learning', 'Machine', 'Learning', 'Rajendra']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUSS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
# stemming | lemmatization -> converts words into thier root form

from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

print(stemmer.stem("playing"))
print(stemmer.stem("played"))
print(stemmer.stem("player"))

print(stemmer.stem("running"))
print(stemmer.stem("runner"))
# Out:
# play
# play
# player
# run
# runner

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

text = "hi i,m shreya."
tokens = word_tokenize(text) # tokenize
print(tokens)

words = word_tokenize(text)
print("tokenize")
print(words)

print("PorterStemmer")
print(stemmer.stem("hi i'm shreya."))
# Out:
# ['hi', 'i', ',', 'm', 'shreya', '.']
# tokenize
# ['hi', 'i', ',', 'm', 'shreya', '.']
# PorterStemmer
# hi i'm shreya.
